# %% [markdown]
# # Black Friday Sale Project(data analysis)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
max_age =df['Age'].max()
max_age
# Out:
# '55+'

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
df.shape
# Out:
# (550068, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %% [markdown]
# ## Task to perform

# %% [markdown]
# ### 1.  The purchase col column is the Target Variable, perform Univariate Analysis and Bivariate Analysis w.r.t the Purchase.

# %% [markdown]
# ### Univariate Analysis

# %%
#We will use the describe() function for the purchase column to get the overview of the central tendencies

df['Purchase'].describe()
# Out:
# count    550068.000000
# mean       9263.968713
# std        5023.065394
# min          12.000000
# 25%        5823.000000
# 50%        8047.000000
# 75%       12054.000000
# max       23961.000000
# Name: Purchase, dtype: float64

# %%
# we will use histogram to show the frequency distribution of purchase amount

plt.hist(df['Purchase'], bins =20, color='blue' , alpha=0.7)
plt.xlabel('Purchase Amount')
plt.ylabel('Frequency')
plt.title('Purchase Amount Distribution')
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
# For Bivariate analysis we will use boxplot to show the correlation between two variables i.e. 'Purchase' and 'Gender'

# %%
sns.boxplot(x='Gender', y='Purchase', data=df)
plt.xlabel('Gender')
plt.ylabel('Purchase')
plt.title('Purchase Amount Distribution by Gender')
plt.show()

# %%
# We can also check the strength of the correltion column i.e. 'Purchase'

# %%
correlation_matrix = df.corr()
purchase_correlation= correlation_matrix['Purchase']
print(purchase_correlation)
# Out:
# User_ID               0.004716
# Occupation            0.020833
# Marital_Status       -0.000463
# Product_Category_1   -0.343703
# Product_Category_2   -0.209918
# Product_Category_3   -0.022006
# Purchase              1.000000
# Name: Purchase, dtype: float64
# C:\Users\Dell\AppData\Local\Temp\ipykernel_13664\287944071.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %% [markdown]
# ### 2. Data Preprocessing

# %%
#1. Check basic statistics of the dataset

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
#2. Check for missing values in the data

missing_value = df.isna()

missing_summary = missing_value.sum()
missing_summary
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
#3. Check for unique values in data

unique_counts = df.nunique()
unique_counts
# Out:
# User_ID                        5891
# Product_ID                     3631
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               20
# Product_Category_2               17
# Product_Category_3               15
# Purchase                      18105
# dtype: int64

# %% [markdown]
# # We will perform EDA

# %%
# We will check the purchase distribution

plt.figure(figsize=(8,4))
sns.histplot(data=df, x='Purchase', bins=20, kde=True )
plt.xlabel('Purchase')
plt.ylabel('Frequency')
plt.title('Purchase Amount Distribution')
plt.show()

# %%
# Check for outliers
# we will be detecting and checking for all the outliers in our dataset
# we will calculate quartiles and IQR

Q1 = df['Purchase'].quantile(0.25)
Q3 = df['Purchase'].quantile(0.75)
IQR = Q3-Q1

# we will define upper and lower bounds for the potential outliers

lower_bound= Q1 -1.5*IQR
upper_bound = Q3 +1.5*IQR

# now we will found the outliers

outliers = df[(df['Purchase']<lower_bound) | (df['Purchase']>upper_bound)]
outliers.head()
# Out:
#       User_ID Product_ID Gender    Age  Occupation City_Category  \
# 343   1000058  P00117642      M  26-35           2             B
# 375   1000062  P00119342      F  36-45           3             A
# 652   1000126  P00087042      M  18-25           9             B
# 736   1000139  P00159542      F  26-35          20             C
# 1041  1000175  P00052842      F  26-35           2             B
#
#      Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 343                           3               0                  10
# 375                           1               0                  10
# 652                           1               0                  10
# 736                           2               0                  10
# 1041                          1               0                  10
#
#       Product_Category_2  Product_Category_3  Purchase
# 343                 16.0                 NaN     23603
# ...

# %%
#After detecting the outliers we will show the outliers in boxplot

plt.figure(figsize=(6,4))
sns.boxplot(data=df, y='Purchase')
plt.title('Outliers present in dataset')
plt.show()

# %%
# Drop unnecessary fields
# We will be dropping product category_3 column as it has most nan values

df.drop(columns= 'Product_Category_3', inplace=True)

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Purchase'],
#       dtype='object')

# %%
#Convert categorical data into integer using map function (e.g 'Gender' column)
# In this dataframe we are going to change the gender column into integer 

gender_int = {'M' : 0 , 'F': 1}
df['Gender'] = df['Gender'].map(gender_int)
df.head()

# now you all can see that before in the gender field we had F & M and we can see that it's 1 & 0
# Out:
#    User_ID Product_ID  Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042       1  0-17          10             A
# 1  1000001  P00248942       1  0-17          10             A
# 2  1000001  P00087842       1  0-17          10             A
# 3  1000001  P00085442       1  0-17          10             A
# 4  1000002  P00285442       0   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
# Now we will be checking for the missing values in the dataframe 
#and after droping we will replace it with the mean of the column

missing_values = df.isnull().sum()
missing_values
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
# as we can see that there are two columns in the dataframe which are having missing values and now we will replace the 
#missing values with their mean of the columns

mean_values = df['Product_Category_2'].mean()
df['Product_Category_2'].fillna(mean_values, inplace = True)

# %%
mean_values1 = df['Product_Category_3'].mean()
df['Product_Category_3'].fillna(mean_values1, inplace=True)

# %%
# Rename columns

df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
# In this code we will change the name of the column: 'Gender' to 'Sex'

column_rename = {'Gender': 'Sex'}
df.rename(columns=column_rename, inplace=True)
df.head()
#as you can see that we have changed the column name from 'Gender' to 'Sex'
# Out:
#    User_ID Product_ID  Sex   Age  Occupation City_Category  \
# 0  1000001  P00069042    1  0-17          10             A
# 1  1000001  P00248942    1  0-17          10             A
# 2  1000001  P00087842    1  0-17          10             A
# 3  1000001  P00085442    1  0-17          10             A
# 4  1000002  P00285442    0   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0            9.842329           12.668243      8370
# 1            6.000000           14.000000     15200
# 2            9.842329           12.668243      1422
# ...

# %%
# Map range variables into integers (e.g 'Age' column)
#as you can check in the table that in the age column we have ranges and we will be changing it into integers

age_mapping= {'0-17': 1,
             '18-25': 2,
             '26-35': 3,
             '36-50':4,
             '55+':5}

df['Age']=df['Age'].map(age_mapping)
df.tail()
# Out:
#         User_ID Product_ID  Sex  Age  Occupation City_Category  \
# 550063  1006033  P00372445    0  NaN          13             B
# 550064  1006035  P00375436    1  3.0           1             C
# 550065  1006036  P00375436    1  3.0          15             B
# 550066  1006038  P00375436    1  5.0           1             C
# 550067  1006039  P00371644    1  NaN           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 550063            9.842329           12.668243       368
# ...

# %%
# Remember the most important thing before jumping on the visualization part you would have to refresh your dataframe
#before visualizing your data because there are two types of data (Numerical and Categorical)

# %% [markdown]
# # DATA VISUALIZATION

# %%
# we will visualization every individual columns

# %%
# Visualize numeric columns using histograms and box plots
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns
for column in numeric_columns:
    plt.figure(figsize=(8, 6))
    sns.histplot(data=df, x=column, kde=True)
    plt.title(f'Histogram of {column}')
    plt.show()
    
    plt.figure(figsize=(8, 6))
    sns.boxplot(data=df, y=column)
    plt.title(f'Box Plot of {column}')
    plt.show()

# Visualize categorical columns using bar plots
categorical_columns = df.select_dtypes(include=['object']).columns
for column in categorical_columns:
    plt.figure(figsize=(8, 6))
    sns.countplot(data=df, x=column)
    plt.title(f'Count Plot of {column}')
    plt.xticks(rotation=45)
    plt.show()

# %%
# We have to visualize the two columns i.e. Age vs Purchased

plt.figure(figsize=(8,4))
sns.boxplot(x='Age', y='Purchase',data=df)
plt.xlabel('Age')
plt.ylabel('Purchase Amount')
plt.title('Age vs Purchase')
plt.show()

# %%
#Occupation vs Purchased
plt.figure(figsize=(8,4))
sns.boxplot(x='Occupation', y='Purchase',data=df)
plt.xlabel('Occupation')
plt.ylabel('Purchase Amount')
plt.title('Occupation vs Purchase')
plt.show()

# %%
# Productcategory1 vs Purchased

plt.figure(figsize=(8,4))
sns.boxplot(x='Product_Category_1', y='Purchase',data=df)
plt.xlabel('Product_Category_1')
plt.ylabel('Purchase Amount')
plt.title('Product_Category_1 vs Purchase')
plt.show()

# %%
# In this City category pie chart we will create a pie chart

city_counts = df['City_Category'].value_counts()
plt.figure(figsize=(8,4))
plt.pie(city_counts, labels=city_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('City Category Distribution')
plt.show()

# %% [markdown]
# # Thank You we are Done here.

# %%
output_file = 'Final_black_friday_sale.csv'  # Specify the desired output file name
df.to_csv(output_file, index=False)  # Set index=False to exclude index column in Excel

print(f"DataFrame saved to {output_file}")
# Out:
# DataFrame saved to Final_black_friday_sale.csv
